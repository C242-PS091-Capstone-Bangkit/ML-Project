# %% [markdown]
# <a href="https://colab.research.google.com/github/C242-PS091-Capstone-Bangkit/ML-Project/blob/main/SkinCondition/Skin_Condition_Model_InceptionV3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Model 2: Using CNN's with the Skin Condition Dataset
#
# For the first model we will use the `skin condition` dataset to train a model that can classify 5 skin condition. For this, we will create own Convolutional Neural Network in Tensorflow and leverage Keras' image preprocessing utilities. In addition, we also tried the pre-trained model from InceptionV3.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Install Required Libraries

# %% [markdown]
# Before we proceed with dataset, let's first install the required libraries to ensure everything is set up correctly for the next steps.

# %%
import os
import pickle
import random
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from google.colab import files

# %% [markdown]
# Since we have already installed the required libraries, we can now proceed to the next step, which is **Pre-Processing the Dataset**.

# %% [markdown]
# <a name="2"></a>
# ## Pre-Processing the Dataset
#
# Let's explore the dataset in the folder `./SkinCondition`. There is a subdirectory for each skin condition class, which consists of images representing various conditions, namely acne, dark spots, large pores, normal skin, and wrinkles. The complete directory tree looks like this:
#
#
# ```
# .
# └── SkinCondition/
#     ├── acne/
#     │   ├── acne_1.jpg
#     │   ├── acne_2.jpg
#     │   └── ...
#     └── dark spot/
#         ├── darkspot_1.jpg
#         ├── darkspot_2.jpg
#     |   └── ...
#     └── large pores/
#         ├── largepores_1.jpg
#         ├── largepores_2.jpg
#     |   └── ...
#     └── normal/
#         ├── normal_1.jpg
#         ├── normal_2.jpg
#     |   └── ...
#     └── wrinkles/
#         ├── wrinkles_1.jpg
#         ├── wrinkles_2.jpg
#         └── ...
#
# ```

# %% [markdown]
# ### Load Image

# %% [markdown]
# Before we begin building the model, let's load an image to explore it's content and understand it's properties. This will help us get a clearer idea of the data we're working with and ensure that we can process the images correctly for the next steps.

# %%
DATA_DIR = '/content/drive/My Drive/Skin Condition/SkinCondition'

data_dir_acne = os.path.join(DATA_DIR, 'acne')
data_dir_darkspot = os.path.join(DATA_DIR, 'dark spot')
data_dir_largepores = os.path.join(DATA_DIR, 'large pores')
data_dir_wrinkles = os.path.join(DATA_DIR, 'wrinkles')
data_dir_normal = os.path.join(DATA_DIR, 'normal')

print(f"There are {len(os.listdir(data_dir_acne))} images of acne.")
print(f"There are {len(os.listdir(data_dir_darkspot))} images of dark spot.")
print(f"There are {len(os.listdir(data_dir_largepores))} images of large pores.")
print(f"There are {len(os.listdir(data_dir_wrinkles))} images of wrinkles.")
print(f"There are {len(os.listdir(data_dir_normal))} images of normal.")
# Out:
# There are 420 images of acne.
# There are 430 images of dark spot.
# There are 420 images of large pores.
# There are 420 images of wrinkles.
# There are 420 images of normal.

# %% [markdown]
# While it's useful to know the number of images in each class, let's visualize a few of them to gain a clearer understanding of the types of images in the dataset:

# %%
acne_filenames = [os.path.join(data_dir_acne, filename) for filename in os.listdir(data_dir_acne)]
darkspot_filenames = [os.path.join(data_dir_darkspot, filename) for filename in os.listdir(data_dir_darkspot)]
largepores_filenames = [os.path.join(data_dir_largepores, filename) for filename in os.listdir(data_dir_largepores)]
wrinkles_filenames = [os.path.join(data_dir_wrinkles, filename) for filename in os.listdir(data_dir_wrinkles)]
normal_filenames = [os.path.join(data_dir_normal, filename) for filename in os.listdir(data_dir_normal)]

num_examples = 4

random_acne = random.sample(acne_filenames, num_examples)
random_darkspot = random.sample(darkspot_filenames, num_examples)
random_largepores = random.sample(largepores_filenames, num_examples)
random_wrinkles = random.sample(wrinkles_filenames, num_examples)
random_normal = random.sample(normal_filenames, num_examples)

fig, axes = plt.subplots(5, num_examples, figsize=(14, 14))
fig.suptitle('Skin Type Images', fontsize=16)

# Plot the first 4 images of each class
for i, acne_image in enumerate(random_acne):
    img = tf.keras.utils.load_img(acne_image)
    axes[0, i].imshow(img)
    axes[0, i].set_title(f'Example Acne Skin {i}')

for i, darkspot_image in enumerate(random_darkspot):
    img = tf.keras.utils.load_img(darkspot_image)
    axes[1, i].imshow(img)
    axes[1, i].set_title(f'Example Dark Spot Skin {i}')

for i, largepores_image in enumerate(random_largepores):
    img = tf.keras.utils.load_img(largepores_image)
    axes[2, i].imshow(img)
    axes[2, i].set_title(f'Example Large Pores Skin {i}')

for i, wrinkles_image in enumerate(random_wrinkles):
    img = tf.keras.utils.load_img(wrinkles_image)
    axes[3, i].imshow(img)
    axes[3, i].set_title(f'Example Wrinkles Skin {i}')

for i, normal_image in enumerate(random_normal):
    img = tf.keras.utils.load_img(normal_image)
    axes[4, i].imshow(img)
    axes[4, i].set_title(f'Example Normal Skin {i}')
plt.show()

# %% [markdown]
# These example images from each skin condition class are certainly interesting! Notice that these images come in all kinds of resolutions!

# %% [markdown]
# ### Split Dataset

# %% [markdown]
# Once we have loaded the images, the next step is to split the dataset into training and validation sets. This split ensures that we can train our model on one portion of the data while using another portion to evaluate its performance.

# %%
def train_val_datasets():
    training_dataset, validation_dataset = tf.keras.utils.image_dataset_from_directory(
        directory= DATA_DIR,
        image_size=(224, 224),
        batch_size=128,
        label_mode='categorical',
        validation_split=0.20,
        subset='both',
        seed=42
    )

    return training_dataset, validation_dataset

# %%
training_dataset, validation_dataset = train_val_datasets()
# Out:
# Found 2077 files belonging to 5 classes.
# Using 1662 files for training.
# Using 415 files for validation.

# %% [markdown]
# At this point, we now have two separate datasets, one dedicated to training the model and the other for validating its performance.
#
# The training dataset will be used to teach the model to recognize patterns and make predictions, while the validation dataset will allow we to assess how well the model generalizes to new, unseen data, helping to fine-tune the model and avoid overfitting.

# %%
for images, labels in training_dataset.take(1):
	example_batch_images = images
	example_batch_labels = labels

print(f"Maximum pixel value of images: {np.max(example_batch_images)}\n")
print(f"Shape of batch of images: {example_batch_images.shape}")
print(f"Shape of batch of labels: {example_batch_labels.shape}")
# Out:
# Maximum pixel value of images: 255.0
#
# Shape of batch of images: (128, 224, 224, 3)
# Shape of batch of labels: (128, 5)

# %% [markdown]
# Keep in mind that the pixel values of the images are not normalized yet, so we need to add a Rescaling layer in the model to scale these values by a factor of 1./255.

# %% [markdown]
# ### Data Augmentation

# %% [markdown]
# With the data in the approciate format, the next step is to apply data augmentation to enhance the model's robustness by creating varied image versions through transformations such as rotation, flipping, scaling, or color adjustments.

# %%
def create_augmentation_model():
    return tf.keras.Sequential([
        tf.keras.layers.RandomFlip("horizontal"),
        tf.keras.layers.RandomRotation(0.1, fill_mode="nearest"),
        tf.keras.layers.RandomTranslation(0.1, 0.1, fill_mode="nearest"),
        tf.keras.layers.RandomZoom(0.1, fill_mode="nearest"),
        tf.keras.layers.RandomContrast(0.1),
    ])

augmentation_model = create_augmentation_model()
train_dataset = training_dataset.map(lambda x, y: (augmentation_model(x), y))

# %%
def demo_augmentation(sample_image, model, num_aug):

    image_preview = []

    sample_image_pil = tf.keras.utils.array_to_img(sample_image)

    image_preview.append(sample_image_pil)

    for i in range(NUM_AUG):
        sample_image_aug = model(tf.expand_dims(sample_image, axis=0))
        sample_image_aug_pil = tf.keras.utils.array_to_img(tf.squeeze(sample_image_aug))
        image_preview.append(sample_image_aug_pil)

    fig, axes = plt.subplots(1, NUM_AUG + 1, figsize=(12, 12))

    for index, ax in enumerate(axes):
        ax.imshow(image_preview[index])
        ax.set_axis_off()

        if index == 0:
            ax.set_title('original')
        else:
            ax.set_title(f'augment {index}')

# %%
NUM_AUG = 5

sample_batch = list(training_dataset.take(1))[0][0]

demo_augmentation(sample_batch[0], create_augmentation_model(), NUM_AUG)
demo_augmentation(sample_batch[1], create_augmentation_model(), NUM_AUG)
demo_augmentation(sample_batch[2], create_augmentation_model(), NUM_AUG)
demo_augmentation(sample_batch[3], create_augmentation_model(), NUM_AUG)

del sample_batch

# %% [markdown]
# Now that we have applied data augmentation, the datasets with varied image versions are ready, and we can proceed to the next step, which is **Build and Train The Model**.

# %% [markdown]
# ## Build and Train The Model

# %% [markdown]
# After completing the pre-processing steps, we will proceed by building the model using pre-trained model from InceptionV3 and perform fine-tuning starting from layer 150 to adapt the model to our specific dataset.

# %%
def create_transfer_learning_model():
    base_model = tf.keras.applications.InceptionV3(
        input_shape=(224, 224, 3),
        include_top=False,
        weights='imagenet'
    )
    base_model.trainable = False

    inputs = tf.keras.Input(shape=(224, 224, 3))
    x = tf.keras.layers.Rescaling(1./255)(inputs)
    x = base_model(x, training=False)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    x = tf.keras.layers.Dense(128, activation='relu',
        kernel_regularizer=tf.keras.regularizers.l2(0.01)
    )(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(5, activation='softmax')(x)

    model = tf.keras.Model(inputs, outputs)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    fine_tune_at = 150
    base_model.trainable = True
    for layer in base_model.layers[:fine_tune_at]:
        layer.trainable = False

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# %% [markdown]
# The next cell allows us to examine the total number of parameters in the model.

# %%
model = create_transfer_learning_model()
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)           │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ rescaling_1 (Rescaling)              │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ inception_v3 (Functional)            │ (None, 5, 5, 2048)          │      21,802,784 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_1           │ (None, 2048)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │         262,272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 5)                   │             645 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 22,065,701 (84.17 MB)
#  Trainable params: 17,629,893 (67.25 MB)
#  Non-trainable params: 4,435,808 (16.92 MB)

# %% [markdown]
# Now, we can begin training the model. We will use 100 epochs for the training process.

# %%
history = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=100
)
# Out:
# Epoch 1/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 372s 26s/step - accuracy: 0.2958 - loss: 4.1203 - val_accuracy: 0.4747 - val_loss: 3.7941
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 70s 3s/step - accuracy: 0.6432 - loss: 3.3402 - val_accuracy: 0.6072 - val_loss: 3.4860
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.7831 - loss: 2.9494 - val_accuracy: 0.6867 - val_loss: 3.2970
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.8374 - loss: 2.7783 - val_accuracy: 0.7060 - val_loss: 3.3289
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.8871 - loss: 2.6048 - val_accuracy: 0.7518 - val_loss: 3.1724
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.9094 - loss: 2.5113 - val_accuracy: 0.7783 - val_loss: 2.9945
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 42s 3s/step - accuracy: 0.9320 - loss: 2.4140 - val_accuracy: 0.8169 - val_loss: 2.7837
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.9287 - loss: 2.3571 - val_accuracy: 0.8554 - val_loss: 2.6211
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.9558 - loss: 2.2486 - val_accuracy: 0.8867 - val_loss: 2.4641
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.9659 - loss: 2.1903 - val_accuracy: 0.9060 - val_loss: 2.3990
# Epoch 11/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.9664 - loss: 2.1319 - val_accuracy: 0.9157 - val_loss: 2.3345
# Epoch 12/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.9754 - loss: 2.0671 - val_accuracy: 0.9205 - val_loss: 2.2140
# Epoch 13/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.9667 - loss: 2.0438 - val_accuracy: 0.9277 - val_loss: 2.1741
# Epoch 14/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.9764 - loss: 1.9779 - val_accuracy: 0.9373 - val_loss: 2.1138
# Epoch 15/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 42s 3s/step - accuracy: 0.9892 - loss: 1.9116 - val_accuracy: 0.9446 - val_loss: 2.0334
# Epoch 16/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.9861 - loss: 1.8765 - val_accuracy: 0.9614 - val_loss: 1.9466
# Epoch 17/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.9829 - loss: 1.8352 - val_accuracy: 0.9518 - val_loss: 1.9461
# Epoch 18/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.9853 - loss: 1.7827 - val_accuracy: 0.9542 - val_loss: 1.8879
# Epoch 19/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.9886 - loss: 1.7320 - val_accuracy: 0.9590 - val_loss: 1.8276
# Epoch 20/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.9874 - loss: 1.7040 - val_accuracy: 0.9614 - val_loss: 1.7951
# Epoch 21/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 36s 3s/step - accuracy: 0.9940 - loss: 1.6378 - val_accuracy: 0.9687 - val_loss: 1.7631
# Epoch 22/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.9954 - loss: 1.5927 - val_accuracy: 0.9542 - val_loss: 1.7607
# Epoch 23/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.9940 - loss: 1.5489 - val_accuracy: 0.9542 - val_loss: 1.7040
# Epoch 24/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 42s 3s/step - accuracy: 0.9945 - loss: 1.5111 - val_accuracy: 0.9590 - val_loss: 1.6292
# Epoch 25/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.9950 - loss: 1.4672 - val_accuracy: 0.9711 - val_loss: 1.5667
# Epoch 26/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.9941 - loss: 1.4276 - val_accuracy: 0.9663 - val_loss: 1.5329
# Epoch 27/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.9952 - loss: 1.3900 - val_accuracy: 0.9566 - val_loss: 1.4935
# Epoch 28/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.9886 - loss: 1.3678 - val_accuracy: 0.9663 - val_loss: 1.4485
# Epoch 29/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.9958 - loss: 1.3126 - val_accuracy: 0.9711 - val_loss: 1.3936
# Epoch 30/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.9924 - loss: 1.2796 - val_accuracy: 0.9783 - val_loss: 1.3522
# Epoch 31/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.9931 - loss: 1.2466 - val_accuracy: 0.9687 - val_loss: 1.3415
# Epoch 32/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.9934 - loss: 1.2046 - val_accuracy: 0.9687 - val_loss: 1.3407
# Epoch 33/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.9903 - loss: 1.1781 - val_accuracy: 0.9711 - val_loss: 1.2555
# Epoch 34/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 43s 3s/step - accuracy: 0.9979 - loss: 1.1297 - val_accuracy: 0.9783 - val_loss: 1.2222
# Epoch 35/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.9945 - loss: 1.0989 - val_accuracy: 0.9735 - val_loss: 1.1882
# Epoch 36/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.9966 - loss: 1.0639 - val_accuracy: 0.9735 - val_loss: 1.1504
# Epoch 37/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 36s 3s/step - accuracy: 0.9973 - loss: 1.0286 - val_accuracy: 0.9663 - val_loss: 1.1115
# Epoch 38/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.9933 - loss: 1.0012 - val_accuracy: 0.9687 - val_loss: 1.1003
# Epoch 39/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.9983 - loss: 0.9629 - val_accuracy: 0.9735 - val_loss: 1.0709
# Epoch 40/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 42s 3s/step - accuracy: 0.9978 - loss: 0.9331 - val_accuracy: 0.9711 - val_loss: 1.0466
# Epoch 41/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.9984 - loss: 0.9056 - val_accuracy: 0.9663 - val_loss: 1.0441
# Epoch 42/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.9951 - loss: 0.8766 - val_accuracy: 0.9663 - val_loss: 1.0050
# Epoch 43/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.9984 - loss: 0.8460 - val_accuracy: 0.9759 - val_loss: 0.9622
# Epoch 44/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.9967 - loss: 0.8202 - val_accuracy: 0.9711 - val_loss: 0.9478
# Epoch 45/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.9973 - loss: 0.7935 - val_accuracy: 0.9735 - val_loss: 0.9133
# Epoch 46/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.9921 - loss: 0.7868 - val_accuracy: 0.9759 - val_loss: 0.8826
# Epoch 47/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.9976 - loss: 0.7442 - val_accuracy: 0.9614 - val_loss: 0.8813
# Epoch 48/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.9937 - loss: 0.7301 - val_accuracy: 0.9639 - val_loss: 0.8325
# Epoch 49/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 43s 3s/step - accuracy: 0.9961 - loss: 0.7059 - val_accuracy: 0.9735 - val_loss: 0.8017
# Epoch 50/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.9938 - loss: 0.6869 - val_accuracy: 0.9759 - val_loss: 0.7610
# Epoch 51/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.9989 - loss: 0.6480 - val_accuracy: 0.9783 - val_loss: 0.7317
# Epoch 52/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 1.0000 - loss: 0.6219 - val_accuracy: 0.9783 - val_loss: 0.7033
# Epoch 53/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 36s 3s/step - accuracy: 0.9984 - loss: 0.6024 - val_accuracy: 0.9735 - val_loss: 0.6891
# Epoch 54/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 42s 3s/step - accuracy: 0.9948 - loss: 0.5876 - val_accuracy: 0.9759 - val_loss: 0.6752
# Epoch 55/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.9957 - loss: 0.5643 - val_accuracy: 0.9735 - val_loss: 0.6825
# Epoch 56/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.9978 - loss: 0.5436 - val_accuracy: 0.9687 - val_loss: 0.6729
# Epoch 57/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 42s 3s/step - accuracy: 0.9990 - loss: 0.5218 - val_accuracy: 0.9711 - val_loss: 0.6275
# Epoch 58/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.9997 - loss: 0.5022 - val_accuracy: 0.9783 - val_loss: 0.5982
# Epoch 59/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 42s 3s/step - accuracy: 0.9973 - loss: 0.4928 - val_accuracy: 0.9807 - val_loss: 0.5869
# Epoch 60/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.9966 - loss: 0.4736 - val_accuracy: 0.9735 - val_loss: 0.5679
# Epoch 61/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.9944 - loss: 0.4601 - val_accuracy: 0.9807 - val_loss: 0.5408
# Epoch 62/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.9993 - loss: 0.4376 - val_accuracy: 0.9783 - val_loss: 0.5239
# Epoch 63/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.9994 - loss: 0.4182 - val_accuracy: 0.9783 - val_loss: 0.5071
# Epoch 64/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.9974 - loss: 0.4052 - val_accuracy: 0.9831 - val_loss: 0.4880
# Epoch 65/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.9995 - loss: 0.3896 - val_accuracy: 0.9759 - val_loss: 0.4682
# Epoch 66/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.9950 - loss: 0.3865 - val_accuracy: 0.9735 - val_loss: 0.4809
# Epoch 67/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.9976 - loss: 0.3687 - val_accuracy: 0.9735 - val_loss: 0.4750
# Epoch 68/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.9977 - loss: 0.3533 - val_accuracy: 0.9783 - val_loss: 0.4472
# Epoch 69/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.9981 - loss: 0.3397 - val_accuracy: 0.9855 - val_loss: 0.4066
# Epoch 70/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.9991 - loss: 0.3231 - val_accuracy: 0.9831 - val_loss: 0.4082
# Epoch 71/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.9975 - loss: 0.3216 - val_accuracy: 0.9807 - val_loss: 0.3991
# Epoch 72/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.9995 - loss: 0.2967 - val_accuracy: 0.9807 - val_loss: 0.3947
# Epoch 73/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.9999 - loss: 0.2860 - val_accuracy: 0.9807 - val_loss: 0.3921
# Epoch 74/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.9961 - loss: 0.2784 - val_accuracy: 0.9783 - val_loss: 0.3842
# Epoch 75/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 43s 3s/step - accuracy: 1.0000 - loss: 0.2654 - val_accuracy: 0.9807 - val_loss: 0.3747
# Epoch 76/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 1.0000 - loss: 0.2539 - val_accuracy: 0.9783 - val_loss: 0.3634
# Epoch 77/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.9989 - loss: 0.2487 - val_accuracy: 0.9783 - val_loss: 0.3530
# Epoch 78/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.9978 - loss: 0.2422 - val_accuracy: 0.9807 - val_loss: 0.3372
# Epoch 79/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.9996 - loss: 0.2264 - val_accuracy: 0.9807 - val_loss: 0.3261
# Epoch 80/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.9989 - loss: 0.2188 - val_accuracy: 0.9807 - val_loss: 0.3226
# Epoch 81/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.9995 - loss: 0.2093 - val_accuracy: 0.9735 - val_loss: 0.3237
# Epoch 82/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 1.0000 - loss: 0.2007 - val_accuracy: 0.9807 - val_loss: 0.2998
# Epoch 83/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.9995 - loss: 0.1934 - val_accuracy: 0.9807 - val_loss: 0.2839
# Epoch 84/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.9971 - loss: 0.1901 - val_accuracy: 0.9783 - val_loss: 0.2885
# Epoch 85/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.9999 - loss: 0.1788 - val_accuracy: 0.9735 - val_loss: 0.2937
# Epoch 86/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 1.0000 - loss: 0.1710 - val_accuracy: 0.9735 - val_loss: 0.2853
# Epoch 87/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.9984 - loss: 0.1677 - val_accuracy: 0.9711 - val_loss: 0.2644
# Epoch 88/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.9987 - loss: 0.1593 - val_accuracy: 0.9759 - val_loss: 0.2534
# Epoch 89/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.9992 - loss: 0.1524 - val_accuracy: 0.9783 - val_loss: 0.2458
# Epoch 90/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.9987 - loss: 0.1479 - val_accuracy: 0.9783 - val_loss: 0.2437
# Epoch 91/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.9983 - loss: 0.1436 - val_accuracy: 0.9759 - val_loss: 0.2469
# Epoch 92/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.9998 - loss: 0.1339 - val_accuracy: 0.9735 - val_loss: 0.2453
# Epoch 93/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.9964 - loss: 0.1366 - val_accuracy: 0.9735 - val_loss: 0.2377
# Epoch 94/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.9986 - loss: 0.1252 - val_accuracy: 0.9687 - val_loss: 0.2264
# Epoch 95/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.9968 - loss: 0.1221 - val_accuracy: 0.9735 - val_loss: 0.2215
# Epoch 96/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.9991 - loss: 0.1143 - val_accuracy: 0.9783 - val_loss: 0.2150
# Epoch 97/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.9996 - loss: 0.1090 - val_accuracy: 0.9783 - val_loss: 0.2218
# Epoch 98/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 42s 3s/step - accuracy: 0.9979 - loss: 0.1138 - val_accuracy: 0.9735 - val_loss: 0.2182
# Epoch 99/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.9982 - loss: 0.1040 - val_accuracy: 0.9735 - val_loss: 0.2076
# Epoch 100/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.9999 - loss: 0.0968 - val_accuracy: 0.9759 - val_loss: 0.2040

# %% [markdown]
# The following code will display the training and validation accuracy achieved at the end of each epoch once the training is complete.

# %%
plt.plot(history.history["accuracy"], label="Training Accuracy")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
plt.legend()
plt.show()

plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend()
plt.show()

# %% [markdown]
# Now that we have successfully built and trained the model using the prepared dataset to achieve high accuracy, we can proceed to the next step, which is **Evaluate the Model**.

# %% [markdown]
# ## Evaluate the Model

# %% [markdown]
# After training the model, we evaluate its performance using the confusion matrix. We can also view the Classification Report, which includes precision, recall, f1-score, and support for each class.
#
# But, before creating the confusion matrix, we need to ensure that the labels are correctly assigned and match the predicted values with the actual ones.

# %%
dataset = datasets.ImageFolder(DATA_DIR, transform=transforms.ToTensor())
print(dataset.class_to_idx)
# Out:
# {'acne': 0, 'dark spot': 1, 'large pores': 2, 'normal': 3, 'wrinkles': 4}

# %% [markdown]
# After ensuring the labels are correctly assigned, we can run the following code to evaluate the model using the confusion matrix.

# %%
y_true = np.concatenate([y for x, y in validation_dataset], axis=0)
y_pred = model.predict(validation_dataset)

y_pred_class = np.argmax(y_pred, axis=1)
y_true_class = np.argmax(y_true, axis=1)

cm = confusion_matrix(y_true_class, y_pred_class)

class_labels = ['Acne', 'Dark Spot', 'Large Pores', 'Normal', 'Wrinkles']

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
disp.plot(cmap='Blues', xticks_rotation=45)

plt.title("Confusion Matrix")
plt.show()

accuracy = accuracy_score(y_true_class, y_pred_class)

print("Classification Report:")
print(classification_report(y_true_class, y_pred_class, target_names=class_labels))
print(f"Accuracy: {accuracy:.2f}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 535ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#         Acne       0.99      0.96      0.97        73
#    Dark Spot       1.00      0.96      0.98        75
#  Large Pores       0.94      0.97      0.95        75
#       Normal       0.97      0.98      0.97        87
#     Wrinkles       0.99      1.00      1.00       105
#
#     accuracy                           0.98       415
#    macro avg       0.98      0.97      0.97       415
# weighted avg       0.98      0.98      0.98       415
#
# Accuracy: 0.98

# %%
threshold = 0.5
y_pred_binary = (y_pred > threshold).astype(int)

accuracy = accuracy_score(y_true, y_pred_binary)
precision = precision_score(y_true, y_pred_binary, average='macro')
recall = recall_score(y_true, y_pred_binary, average='macro')
f1 = f1_score(y_true, y_pred_binary, average='macro')

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Accuracy: 0.9759
# Precision: 0.9757
# Recall: 0.9738
# F1 Score: 0.9746

# %% [markdown]
# After achieving satisfactory performance for classifying each skin condition class, we can save the model using the following code.

# %%
model.save('skin_condition_model.h5')
files.download('skin_condition_model.h5')

# %% [markdown]
# Finally! We have completed all the steps and successfully built a model for skin condition classification, saved in h5 format!
